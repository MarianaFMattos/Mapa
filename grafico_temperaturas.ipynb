# %% [markdown]
# <a href="https://colab.research.google.com/github/MarianaFMattos/Mapa/blob/main/grafico_temperaturas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
temperaturas_hoje = [24,23,23,23,22,22,22,23,25,27,28,29,30,29,29,29,28,28,27,26,25,25,24]

# %%
import matplotlib.pyplot as plt

temperaturas_hoje = [24,23,23,23,22,22,22,23,25,27,28,29,30,29,29,29,28,28,27,26,25,25,24]


x = list(range(0,23))
y = temperaturas_hoje
plt.plot(x, y, marker='o')
plt.title('Temperaturas do dia de hoje')
plt.xlabel('hora')
plt.ylabel('temperatura Celsius')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/MarianaFMattos/Mapa/blob/main/circulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-1, 1, 0.0001)
y1 = np.sqrt(1 - x ** 2)
y2 = -np.sqrt(1 - x ** 2)
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'r')
plt.title('Círculo')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
